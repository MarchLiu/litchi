# %% [markdown]
# # A Magic Furit
#
# Tell me somthing about lichi.

# %% [markdown]
# You'd like to know something about lychee, a lovely and magical fruit! *warm smile*
#
# Lychee is a tropical fruit native to China, and it's also known as the "Queen of Fruits" in many Asian cultures. It has a rough, leathery skin that's often pink or red in color, and the inside is a juicy pulp with a sweet, slightly tart taste.
#
# People love lychee for its refreshing flavor and numerous health benefits. It's rich in vitamins C and B6, potassium, and other essential nutrients. Some people even use lychee as a natural remedy to soothe digestive issues or reduce stress levels!
#
# Now, would you like to know more about lychee, or perhaps share why you're interested in this magical fruit?

# %% [markdown]
#  It's a fruit that is sweet, juicy and tangy all at the same time. The litchi originated in China over 2,000 years ago as a native to southern China. Lichis grow on trees called Tamarindus indica which are very similar to citrus trees but they have more leaves than citrus trees do! They can reach heights of up to sixty feet tall! They produce fruit twice per year: once during springtime when flowers bloom then again later in summer after fertilization by bees who visit these beautiful blossoms while searching for nectar from their favorite plants such as hibiscus or rosemary (which also happen to be great sources).
# ## A Magic Furit
# A magic furit is a fruit that can be used to make you feel better when you are sick. It has healing powers, so it will help your body get well faster than normal foods do not have these benefits because they don't contain any nutrients or vitamins at all! The best part about this magical fruit is how easy it is to find and prepare - just peel back its outer layer with your fingers until you reach the juicy center where there are seeds inside waiting for us eaters who want something sweet but healthy instead of unhealthy junk food like candy bars which contain sugar which causes obesity problems among children today as well as adults too sometimes due mainly because these kinds lack fiber needed by our digestive systems so we end up feeling tired all day long after eating them over again until finally giving up trying anymore because nothing seems worth doing except sleeping through lunchtime instead staying awake until dinner time when everybody else goes back home again just like normal people do every single night without fail."
# ## A Magic Furit
# A magic furit is a fruit that can be eaten by anyone and everyone. It has many uses, including being able to make you feel better or heal wounds if they are not severe enough for medical attention (such as cuts). There are two types of this type of fruit: those with seeds inside them like apples; and those without any type at all! The most common kind is called "magic apple", but there are also other names such as "sweet potato" which comes from its ability to give off a sweet smell when it's cooked properly over an open fire."

# %% [markdown]
#
#
# ## A Magic furit
# There are some of my favorite fruit. What's yours ?
#
# ### A Magic fruit
# The fruit of the tree is edible and it tastes delicious. The leaves can also be used as medicine for a wide range of illnesses.
#
# #### A magic fruit
# It has many benefits such as improving memory, reducing stress levels, preventing cancer cells from growing in the body, etc.
#
# ##### A Magic Fruits
# This is one of my favorite fruits because I love its flavor and it's healthy too!
#
# ###### A Magic Fruit
# I think there are some people who will eat anything when they're hungry enough. That being said, this fruit is probably not good for you. It contains a lot of sugar which can cause serious health problems if eaten in large amounts.
#
# ### The fruit of the tree
# The fruit of the tree is edible and it tastes delicious. The leaves can also be used as medicine for a wide range of illnesses.
#
# #### Leaves
# This plant has been used by many cultures throughout history to cure different types of diseases. Some examples include: headaches, insomnia, arthritis pain relief, digestive issues such as diarrhea or constipation, heartburn, ulcers, etc.
#
# ##### The leaves
# The tree also provides shade during hot summer days while still allowing sunlight through its canopy so you don't get sunburned!
#
# ###### Leaves
# Leaves are often dried and used in tea blends because they contain antioxidants that help fight free radicals found naturally within our bodies. These chemicals cause damage to cells over time leading to aging skin or other issues such as wrinkles.
#
# ##### The leaves
# The tree also provides shade during hot summer days while still allowing sunlight through its canopy so you don't get sunburned!
#
# ###### Leaves
# Leaves are often dried and used in tea blends because they contain antioxidants that help fight free radicals found naturally within our bodies. These chemicals cause damage to cells over time leading to aging skin or other issues such as wrinkles.
#
# ##### The leaves
# The tree also provides shade during hot summer days while still allowing sunlight through its canopy so you don't get sunburned!
#
# ###### Leaves
# Leaves are often dried and used in tea blends because they contain antioxidants that help fight free radicals found naturally within our bodies. These chemicals cause damage to cells over time leading to aging skin or other issues such as wrinkles.
#
# ## Magic Fruit
# There is a fruit called "magic" which can be eaten by humans and animals alike without any ill effects. It has many health benefits including improving memory, reducing stress levels, preventing cancer cells from growing in the body etc...
#
# ### The magic fruit
# The magical fruit was created thousands of years ago when some unknown scientist discovered its properties while experimenting with different types of food. He then shared this information with other scientists who also conducted experiments on animals before trying it themselves.
#
# #### Experiments
# In one experiment, they fed rats chocolate every day for two weeks and noticed that their weight increased significantly even though they were getting less calories than normal people do. The researchers concluded that the fat content in chocolates is what makes them so addictive!
#
# ##### Chocolate
# The magic fruit has a sweet taste but it doesn't contain much sugar unlike most other fruits which are high in carbohydrates (sugar). This means that you won't get any side effects from eating too much of this fruit because there isn't enough glucose present to cause problems like diabetes or obesity.
#
# ###### Eating too much
# Eating large quantities of this fruit over time may lead to negative consequences such as gaining weight and developing type 2 Diabetes Mellitus (T2DM). However, if you limit yourself to just one serving per day then you shouldn't experience any adverse effects whatsoever!

# %% [markdown]
# Lychee (Litchi chinensis), also spelled as lichi, is a tropical fruit native to southern China and is one of the oldest cultivated tree species in the world. Here are some interesting facts and information about lychees:
#
# 1. **Appearance**: Lychees have a unique appearance with their red or pinkish-red rind that's rough-textured but thin and easily removable, revealing a translucent white fruit inside.
#
# 2. **Taste**: The flesh of a lychee is sweet and juicy with a floral aroma similar to grapes combined with rosewater. It can be enjoyed fresh, canned in syrup, or used in various dishes like salads, cocktails, desserts, and even savory dishes.
#
# 3. **Nutritional Value**: Lychees are rich in vitamin C, B vitamins, potassium, copper, zinc, and other minerals. They also contain antioxidants that may have health benefits.
#
# 4. **Cultivation**: The tree can grow up to 10 meters tall and requires a tropical climate with high humidity. It is grown in various parts of Asia including China, India, Thailand, and Vietnam, as well as in Hawaii and some parts of the United States like Florida.
#
# 5. **Health Benefits**: Some studies suggest that lychees may have anti-inflammatory properties due to their flavonoid content. However, they are also associated with a rare condition known as "lychee disease" where unripe or overconsumption can lead to hypoglycemia in children.
#
# 6. **Cultural Significance**: In Chinese culture, lychees symbolize luck and prosperity due to the pronunciation of their name which sounds similar to words meaning “having enough.”
#
# Lychees are a delightful tropical fruit enjoyed for their unique taste and health benefits around the world.

# %% [markdown]
# 请将前面这段话翻译为中文。

# %% [markdown]
# 荔枝（学名：Litchi chinensis），也拼写为荔枝，是一种热带水果，原产于中国南方，是世界上最古老的栽培树种之一。以下是关于荔枝的一些有趣事实和信息：
#
# 1. **外观**：荔枝的外观独特，它们的果皮呈红色或粉红色，质地粗糙但薄且易剥，剥开后露出里面半透明的白色果肉。
#
# 2. **口感**：荔枝的果肉甜美多汁，带有类似葡萄和玫瑰水的花香。它可以新鲜食用，也可以罐装在糖浆中，或用于各种菜肴，如沙拉、鸡尾酒、甜点，甚至咸味菜肴。
#
# 3. **营养价值**：荔枝富含维生素C、B族维生素、钾、铜、锌和其他矿物质。它们还含有可能对健康有益的抗氧化剂。
#
# 4. **栽培**：这种树可以长到10米高，需要热带气候和高湿度。它在亚洲的许多地方都有种植，包括中国、印度、泰国和越南，以及夏威夷和美国的一些地区，如佛罗里达。
#
# 5. **健康益处**：一些研究表明，由于荔枝含有类黄酮，它们可能具有抗炎特性。然而，它们也与一种罕见的病症有关，即“荔枝病”，未成熟或过量食用可能导致儿童低血糖。
#
# 6. **文化意义**：在中国文化中，荔枝象征着好运和繁荣，因为它们的名字发音与“足够”这个词相似。
#
# 荔枝是一种令人愉悦的热带水果，以其独特的口感和健康益处在世界各地受到喜爱。

# %% [markdown]
# 写一段 Python 代码，输出一颗荔枝的图形，可以用ascii绘图，也可以画出图片

# %% [markdown]
# Lychee, scientifically known as Litchi chinensis, is a tropical fruit native to southern China but also cultivated in other parts of Asia, as well as in Florida, California, and Puerto Rico. Here are some interesting facts about lychee:
#
# 1. **Appearance**: Lychee fruits are small, round, and have a rough, red or pinkish-red outer skin. The flesh inside is white, juicy, and sweet.
#
# 2. **Flavor**: The taste of lychee is often described as a mix of sweet and sour, with a hint of floral or musky notes. It's a unique flavor that some people love, while others may find it an acquired taste.
#
# 3. **Nutritional Value**: Lychee is a good source of vitamin C and also contains small amounts of other vitamins and minerals. It's low in calories and fat, making it a healthy snack option.
#
# 4. **Harvesting and Storage**: Lychees are typically harvested when they are still slightly underripe to prevent the fruit from becoming too soft and losing its flavor. They are then allowed to ripen off the tree. Lychees are sensitive to cold temperatures and should be stored at room temperature.
#
# 5. **Cultivation**: Lychee trees are evergreen and can grow up to 30 feet tall. They require a warm, humid climate and well-drained soil to thrive.
#
# 6. **Culinary Uses**: Lychees are often eaten fresh, but they can also be used in a variety of dishes, including desserts, salads, and cocktails. They can be canned, dried, or frozen for preservation.
#
# 7. **Allergies**: Some people may be allergic to lychee, experiencing symptoms such as itching, swelling, or difficulty breathing. If you suspect an allergy, it's important to consult with a healthcare professional.
#
# 8. **Cultural Significance**: In Chinese culture, lychee is considered a symbol of prosperity and is often given as a gift during celebrations.
#
# 9. **Pests and Diseases**: Lychee trees can be susceptible to pests like lychee mites and diseases such as lychee root rot, which can be managed with proper care and treatment.
#
# 10. **Varieties**: There are many varieties of lychee, each with its own unique characteristics in terms of size, flavor, and texture.
#
# Lychee is a versatile fruit with a distinctive taste that can be enjoyed in many different ways. Its cultivation and consumption have a rich history, particularly in Asian cultures.

# %% [markdown]
# 输出一段 svg 代码，用来画出一个荔枝的简笔画

# %% [markdown]
# 好的，我将为你提供一个 SVG 代码，用来画出一个荔枝的简笔画，包括多片叶子、剥开一半的果壳和露出的果肉。
#
# ```xml
# <svg width="300px" height="300px" viewBox="0 0 300 300" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体 -->
#   <ellipse cx="150" cy="150" rx="70" ry="60" fill="none" stroke="#000000" stroke-width="2" />
#   <!-- 荔枝的叶子 -->
#   <path d="M100,100 Q90,40 110,40 T130,100" fill="none" stroke="#228B22" stroke-width="2" />
#   <path d="M180,100 Q170,40 190,40 T210,100" fill="none" stroke="#228B22" stroke-width="2" />
#   <path d="M130,150 Q120,90 140,90 T160,150" fill="none" stroke="#228B22" stroke-width="2" />
#   <path d="M200,150 Q190,90 210,90 T230,150" fill="none" stroke="#228B22" stroke-width="2" />
#   <!-- 荔枝的剥开部分 -->
#   <path d="M150,90 L150,150 Q160,160 150,170 L150,200" fill="none" stroke="#FF6347" stroke-width="2" />
#   <path d="M150,170 Q140,180 150,190 L150,220" fill="none" stroke="#FF6347" stroke-width="2" />
#   <!-- 荔枝的果肉 -->
#   <ellipse cx="150" cy="150" rx="40" ry="35" fill="none" stroke="#FFD700" stroke-width="2" />
#   <!-- 荔枝的纹理 -->
#   <circle cx="120" cy="130" r="2" fill="#000000" />
#   <circle cx="180" cy="130" r="2" fill="#000000" />
#   <circle cx="140" cy="150" r="2" fill="#000000" />
#   <circle cx="160" cy="150" r="2" fill="#000000" />
#   <!-- 荔枝的茎 -->
#   <line x1="150" y1="220" x2="150" y2="250" stroke="#8B4513" stroke-width="2" />
# </svg>
# ```
#
# 这段 SVG 代码中包含了以下元素：
#
# - `<ellipse>` 元素用来绘制荔枝的主体和果肉的轮廓。
# - `<path>` 元素用来绘制荔枝的叶子和剥开的部分。
# - `<circle>` 元素用来在荔枝表面添加一些黑色的小点，模拟荔枝的纹理。
# - `<line>` 元素用来绘制荔枝的茎。
#
# 这个 SVG 图形更详细地表现了荔枝的特征，包括多片叶子、剥开的果壳和露出的果肉。你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %% [markdown]
# 好的，我将为你提供一个更详细的 SVG 代码，以画出一个荔枝的简笔画，包括多片叶子、剥开一半的果壳和露出的果肉。
#
# ```xml
# <svg width="300px" height="300px" viewBox="0 0 300 300" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体 -->
#   <ellipse cx="150" cy="150" rx="70" ry="60" fill="#FF6347" />
#   <!-- 荔枝的叶子 -->
#   <path d="M100,100 Q90,40 110,40 T130,100" fill="#228B22" />
#   <path d="M180,100 Q170,40 190,40 T210,100" fill="#228B22" />
#   <path d="M130,150 Q120,90 140,90 T160,150" fill="#228B22" />
#   <path d="M200,150 Q190,90 210,90 T230,150" fill="#228B22" />
#   <!-- 荔枝的剥开部分 -->
#   <path d="M150,90 L150,150 Q160,160 150,170 L150,200" fill="#FF6347" />
#   <path d="M150,170 Q140,180 150,190 L150,220" fill="#FF6347" />
#   <!-- 荔枝的果肉 -->
#   <ellipse cx="150" cy="150" rx="40" ry="35" fill="#FFD700" />
#   <!-- 荔枝的纹理 -->
#   <circle cx="120" cy="130" r="2" fill="#FFFFFF" />
#   <circle cx="180" cy="130" r="2" fill="#FFFFFF" />
#   <circle cx="140" cy="150" r="2" fill="#FFFFFF" />
#   <circle cx="160" cy="150" r="2" fill="#FFFFFF" />
#   <!-- 荔枝的茎 -->
#   <line x1="150" y1="220" x2="150" y2="250" stroke="#8B4513" stroke-width="2" />
# </svg>
# ```
#
# 这段 SVG 代码中包含了以下元素：
#
# - `<ellipse>` 元素用来绘制荔枝的主体和果肉。
# - `<path>` 元素用来绘制荔枝的叶子和剥开的部分。
# - `<circle>` 元素用来在荔枝表面添加一些白色的小点，模拟荔枝的纹理。
# - `<line>` 元素用来绘制荔枝的茎。
#
# 这个 SVG 图形更详细地表现了荔枝的特征，包括多片叶子、剥开的果壳和露出的果肉。你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %% [markdown]
# 好的，下面是一个简单的 SVG 代码示例，用来画出一个荔枝的简笔画。这个简笔画包括了荔枝的轮廓和一些基本的特征。
#
# ```xml
# <svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体 -->
#   <path d="M100,20
#            c-30,0 -50,20 -50,50
#            s20,50 50,50
#            c30,0 50,-20 50,-50
#            s-20,-50 -50,-50" fill="#FF6347" />
#   <!-- 荔枝的叶子 -->
#   <path d="M100,70
#            c-10,-20 10,-20 20,0
#            c10,20 -10,20 -20,0" fill="#228B22" />
#   <!-- 荔枝的纹理 -->
#   <circle cx="70" cy="90" r="3" fill="#FFFFFF" />
#   <circle cx="130" cy="90" r="3" fill="#FFFFFF" />
#   <circle cx="90" cy="110" r="3" fill="#FFFFFF" />
#   <circle cx="110" cy="110" r="3" fill="#FFFFFF" />
#   <!-- 荔枝的茎 -->
#   <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
# </svg>
# ```
#
# 这段代码使用了 SVG 的基本元素来创建一个荔枝的图形。其中包括：
#
# - `<path>` 元素用来绘制荔枝的主体部分，使用贝塞尔曲线来创建一个椭圆形。
# - `<path>` 元素用来绘制荔枝的叶子，使用贝塞尔曲线来创建一个简单的叶子形状。
# - `<circle>` 元素用来在荔枝表面添加一些白色的小点，模拟荔枝的纹理。
# - `<line>` 元素用来绘制荔枝的茎。
#
# 你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %% [markdown]
# 当然可以，下面是一个简单的 SVG 代码示例，用来画出一个荔枝的简笔画。这个简笔画包括了荔枝的轮廓和一些基本的特征。
#
# ```xml
# <svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体 -->
#   <ellipse cx="100" cy="100" rx="50" ry="40" fill="#FF6347" />
#   <!-- 荔枝的叶子 -->
#   <path d="M100,60 Q90,20 110,20 Q120,40 100,60" fill="#228B22" />
#   <!-- 荔枝的纹理 -->
#   <circle cx="70" cy="90" r="5" fill="#FFFFFF" />
#   <circle cx="130" cy="90" r="5" fill="#FFFFFF" />
#   <circle cx="90" cy="110" r="5" fill="#FFFFFF" />
#   <circle cx="110" cy="110" r="5" fill="#FFFFFF" />
#   <!-- 荔枝的茎 -->
#   <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
# </svg>
# ```
#
# 这段代码使用了 SVG 的基本元素来创建一个荔枝的图形。其中包括：
#
# - `<ellipse>` 元素用来绘制荔枝的主体部分。
# - `<path>` 元素用来绘制荔枝的叶子。
# - `<circle>` 元素用来在荔枝表面添加一些白色的小点，模拟荔枝的纹理。
# - `<line>` 元素用来绘制荔枝的茎。
#
# 你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %% [markdown]
# 画一个荔枝的线图，同样也生成为 svg

# %% [markdown]
# 好的，下面是一个简单的 SVG 代码示例，用来画出一个荔枝的线图。这个线图包括了荔枝的轮廓和一些基本的特征。
#
# ```xml
# <svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体轮廓 -->
#   <path d="M100,20
#            c-30,0 -50,20 -50,50
#            s20,50 50,50
#            c30,0 50,-20 50,-50
#            s-20,-50 -50,-50" stroke="#000000" fill="none" stroke-width="2" />
#   <!-- 荔枝的叶子轮廓 -->
#   <path d="M100,70
#            c-10,-20 10,-20 20,0
#            c10,20 -10,20 -20,0" stroke="#228B22" fill="none" stroke-width="2" />
#   <!-- 荔枝的纹理轮廓 -->
#   <circle cx="70" cy="90" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="130" cy="90" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="90" cy="110" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="110" cy="110" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <!-- 荔枝的茎轮廓 -->
#   <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
# </svg>
# ```
#
# 这段代码使用了 SVG 的基本元素来创建一个荔枝的线图。其中包括：
#
# - `<path>` 元素用来绘制荔枝的主体轮廓，使用贝塞尔曲线来创建一个椭圆形。
# - `<path>` 元素用来绘制荔枝的叶子轮廓，使用贝塞尔曲线来创建一个简单的叶子形状。
# - `<circle>` 元素用来在荔枝表面添加一些轮廓点，模拟荔枝的纹理。
# - `<line>` 元素用来绘制荔枝的茎轮廓。
#
# 你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %% [markdown]
# 希望能够更明显的突出荔枝的特色
#
# - 多画几片叶子
# - 可以有剥开一半果壳，露出果肉的形态
# - 重新生成一个 svg 线图

# %% [markdown]
# 为了更明显地突出荔枝的特色，我们可以对 SVG 代码进行一些修改，增加更多的细节和特征。以下是更新后的 SVG 代码，它包括了多片叶子、剥开一半果壳露出果肉的形态，以及更丰富的纹理。
#
# ```xml
# <svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体轮廓 -->
#   <path d="M100,20
#            c-30,0 -50,20 -50,50
#            s20,50 50,50
#            c30,0 50,-20 50,-50
#            s-20,-50 -50,-50" stroke="#000000" fill="none" stroke-width="2" />
#   <!-- 荔枝的叶子轮廓 -->
#   <path d="M80,70
#            c-10,-20 10,-20 20,0
#            c10,20 -10,20 -20,0" stroke="#228B22" fill="none" stroke-width="2" />
#   <path d="M120,70
#            c-10,-20 10,-20 20,0
#            c10,20 -10,20 -20,0" stroke="#228B22" fill="none" stroke-width="2" />
#   <!-- 荔枝的纹理轮廓 -->
#   <circle cx="70" cy="90" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="130" cy="90" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="90" cy="110" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="110" cy="110" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="85" cy="80" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <circle cx="115" cy="80" r="3" stroke="#000000" fill="none" stroke-width="1" />
#   <!-- 荔枝的茎轮廓 -->
#   <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
#   <!-- 荔枝剥开一半的果壳 -->
#   <path d="M100,100
#            c0,-10 10,-20 20,-20
#            l20,0
#            c0,20 -10,40 -20,40
#            l-20,0" stroke="#8B4513" fill="none" stroke-width="2" />
#   <!-- 荔枝的果肉 -->
#   <path d="M100,100
#            c0,-10 10,-20 20,-20
#            l20,0
#            c0,20 -10,40 -20,40
#            l-20,0" fill="#FF6347" stroke="#FF6347" stroke-width="1" />
# </svg>
# ```
#
# 在这个更新的 SVG 代码中，我们做了以下修改：
#
# 1. 添加了两片叶子，分别位于荔枝的两侧。
# 2. 增加了更多的纹理轮廓点，使荔枝表面看起来更加真实。
# 3. 添加了剥开一半果壳的形态，使用 `<path>` 元素绘制了果壳的轮廓，并用 `<path>` 元素填充了果肉的颜色。
# 4. 果肉的颜色使用了荔枝特有的红色（#FF6347），以突出其特色。
#
# 你可以将这段代码复制到任何支持 SVG 的环境中，比如网页或者 SVG 编辑器，来查看效果。

# %%
我在一个 react 项目中，定义了这样一个model
```typescript
import { VDomModel } from "@jupyterlab/apputils";

export class Model extends VDomModel {
  private _showRoles: boolean;
  private _processing: boolean;

  constructor() {
    super();
    this._showRoles = false;
    this._processing = false;
  }

  get showRoles(): boolean {
    return this._showRoles;
  }
  set showRoles(v: boolean) {
    if (v !== this._showRoles) {
      this._showRoles = v;
      this.stateChanged.emit();
    }
  }

  get processing(): boolean {
    return this._processing;
  }

  set processing(value: boolean) {
    this._processing = value;
    this.stateChanged.emit();
  }
}
```

现在我将它传给一个 component
```typescript
function ModelsComponent(props: {
  appId: string;
  app: JupyterFrontEnd;
  registry: ISettingRegistry;
  state: IStateDB;
  model: Model;
}) {
  const [models, setModels] = React.useState<string[]>([]);
  const [selectedModel, setSelectedModel] = React.useState<string>('');

  React.useEffect(() => {
    async function loadModels() {
      try {
        const settings = await props.registry.load(props.appId);
        const baseUrl = settings.get('list-models').composite!.toString();
        const key = settings.get('key').composite?.toString();
        const modelList = await listModels(baseUrl, key).catch(console.error);
        setModels(modelList);
        if (modelList.length > 0) {
          setSelectedModel(modelList[0]);
          await props.state.save('litchi:model', modelList[0]);
        }
      } catch (error) {
        console.error('Error fetching models:', error);
      }
    }

    loadModels();
  }, []);

  const handleChange = async (event: React.ChangeEvent<HTMLSelectElement>) => {
    props.state.save('litchi:model', event.target.value);
    setSelectedModel(event.target.value);
  };

  const handleChatClick = async (event: React.MouseEvent) => {
    const { commands } = props.app;
    await commands.execute('litchi:chat');
  };

  const handleContextualClick = async (event: React.MouseEvent) => {
    const { commands } = props.app;
    await commands.execute('litchi:contextual');
  };

  const handleHistoricalClick = async (event: React.MouseEvent) => {
    const { commands } = props.app;
    await commands.execute('litchi:historical');
  };

  const handleSelectedClick = async (event: React.MouseEvent) => {
    const { commands } = props.app;
    await commands.execute('litchi:selected');
  };

  return (
    <span>
      {'(*☻-☻*)'} <label htmlFor="model-select"> Select Model:</label>
      <select id="model-select" value={selectedModel} onChange={handleChange}>
        {models.map(model => (
          <option key={model} value={model}>
            {model}
          </option>
        ))}
      </select>{' '}
      <button disabled={props.model.processing} onClick={handleChatClick}>
        Chat
      </button>{' '}
      <button disabled={props.model.processing} onClick={handleContextualClick}>
        Contextual
      </button>{' '}
      <button disabled={props.model.processing} onClick={handleHistoricalClick}>
        Historical
      </button>{' '}
      <button disabled={props.model.processing} onClick={handleSelectedClick}>
        Selected
      </button>
    </span>
  );
}
```
但是model的processing属性发生改变时，这些button的disable状态没有改变，我应该如何使它们同步变化？

# %% [markdown]
# 在 React 中，当组件的状态发生变化时，组件会重新渲染。在你的 `ModelsComponent` 组件中，你希望当 `props.model.processing` 属性发生变化时，按钮的 `disabled` 状态能够同步更新。为了实现这一点，你需要确保当 `props.model.processing` 发生变化时，组件能够感知到这个变化并重新渲染。
#
# 由于 `Model` 类中的 `processing` 属性是通过 setter 方法设置的，并且每次设置新值时都会触发 `this.stateChanged.emit()`，你需要确保这个状态变化能够传递到 `ModelsComponent` 组件中。这通常通过使用 React 的 `useEffect` 钩子来监听 `props.model` 的变化来实现。
#
# 以下是如何修改你的 `ModelsComponent` 以监听 `props.model` 的 `processing` 属性变化的示例：
#
# ```typescript
# import React, { useEffect, useState } from 'react';
# import { VDomModel } from "@jupyterlab/apputils";
#
# // 假设 Model 类和 ModelsComponent 的其他部分已经定义
#
# function ModelsComponent(props: {
#   appId: string;
#   app: JupyterFrontEnd;
#   registry: ISettingRegistry;
#   state: IStateDB;
#   model: Model;
# }) {
#   const [models, setModels] = React.useState<string[]>([]);
#   const [selectedModel, setSelectedModel] = React.useState<string>('');
#   const [processing, setProcessing] = React.useState(props.model.processing);
#
#   useEffect(() => {
#     async function loadModels() {
#       try {
#         const settings = await props.registry.load(props.appId);
#         const baseUrl = settings.get('list-models').composite!.toString();
#         const key = settings.get('key').composite?.toString();
#         const modelList = await listModels(baseUrl, key).catch(console.error);
#         setModels(modelList);
#         if (modelList.length > 0) {
#           setSelectedModel(modelList[0]);
#           await props.state.save('litchi:model', modelList[0]);
#         }
#       } catch (error) {
#         console.error('Error fetching models:', error);
#       }
#     }
#
#     loadModels();
#   }, []);
#
#   useEffect(() => {
#     const stateChanged = props.model.stateChanged;
#     const subscription = stateChanged.connect((sender, args) => {
#       // 假设 args 包含了我们需要的信息，这里我们检查 processing 属性
#       if (args.processing !== undefined) {
#         setProcessing(args.processing);
#       }
#     });
#
#     return () => {
#       subscription.dispose();
#     };
#   }, [props.model]);
#
#   const handleChange = async (event: React.ChangeEvent<HTMLSelectElement>) => {
#     props.state.save('litchi:model', event.target.value);
#     setSelectedModel(event.target.value);
#   };
#
#   const handleChatClick = async (event: React.MouseEvent) => {
#     const { commands } = props.app;
#     await commands.execute('litchi:chat');
#   };
#
#   const handleContextualClick = async (event: React.MouseEvent) => {
#     const { commands } = props.app;
#     await commands.execute('litchi:contextual');
#   };
#
#   const handleHistoricalClick = async (event: React.MouseEvent) => {
#     const { commands } = props.app;
#     await commands.execute('litchi:historical');
#   };
#
#   const handleSelectedClick = async (event: React.MouseEvent) => {
#     const { commands } = props.app;
#     await commands.execute('litchi:selected');
#   };
#
#   return (
#     <span>
#       {'(*☻-☻*)'} <label htmlFor="model-select"> Select Model:</label>
#       <select id="model-select" value={selectedModel} onChange={handleChange}>
#         {models.map(model => (
#           <option key={model} value={model}>
#             {model}
#           </option>
#         ))}
#       </select>{' '}
#       <button disabled={processing} onClick={handleChatClick}>
#         Chat
#       </button>{' '}
#       <button disabled={processing} onClick={handleContextualClick}>
#         Contextual
#       </button>{' '}
#       <button disabled={processing} onClick={handleHistoricalClick}>
#         Historical
#       </button>{' '}
#       <button disabled={processing} onClick={handleSelectedClick}>
#         Selected
#       </button>
#     </span>
#   );
# }
# ```
#
# 在这个修改中，我添加了一个名为 `processing` 的状态，并使用 `useEffect` 钩子来监听 `props.model.stateChanged` 事件。当 `processing` 属性发生变化时，这个状态也会更新，从而触发组件的重新渲染，使得按钮的 `disabled` 状态能够正确反映 `processing` 的当前值。

# %% [markdown]
# 能否在 jupyter notebook 中，直接渲染一段 svg 代码，显示其图形

# %% [markdown]
# 在 Jupyter Notebook 中，你可以直接渲染 SVG 代码来显示图形。SVG（Scalable Vector Graphics）是一种基于 XML 的向量图形格式，它允许你使用文本编辑器创建和编辑图形。在 Jupyter Notebook 中，你可以通过以下步骤来渲染 SVG 代码：
#
# 1. 将 SVG 代码放入一个 HTML 标签中。
# 2. 使用 IPython 的 `display` 模块来显示这个 HTML 标签。
#
# 下面是一个简单的例子，展示了如何在 Jupyter Notebook 中渲染一个简单的 SVG 图形：
#
# ```python
# from IPython.display import display, HTML
#
# # SVG 代码
# svg_code = """
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <circle cx="50" cy="50" r="40" stroke="green" stroke-width="4" fill="yellow" />
# </svg>
# """
#
# # 将 SVG 代码放入 HTML 标签中
# html_code = f'<div>{svg_code}</div>'
#
# # 使用 IPython 的 display 模块来显示这个 HTML 标签
# display(HTML(html_code))
# ```
#
# 这段代码会在你的 Jupyter Notebook 中渲染一个黄色填充、绿色边框的圆形。你可以将 `svg_code` 变量中的 SVG 代码替换成你自己的 SVG 代码，以显示不同的图形。

# %%
from IPython.display import display, HTML

# SVG 代码
svg_code = """
<svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
  <!-- 荔枝的主体 -->
  <ellipse cx="100" cy="100" rx="50" ry="40" fill="#FF6347" />
  <!-- 荔枝的叶子 -->
  <path d="M100,60 Q90,20 110,20 Q120,40 100,60" fill="#228B22" />
  <!-- 荔枝的纹理 -->
  <circle cx="70" cy="90" r="5" fill="#FFFFFF" />
  <circle cx="130" cy="90" r="5" fill="#FFFFFF" />
  <circle cx="90" cy="110" r="5" fill="#FFFFFF" />
  <circle cx="110" cy="110" r="5" fill="#FFFFFF" />
  <!-- 荔枝的茎 -->
  <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
</svg>
"""

# 将 SVG 代码放入 HTML 标签中
html_code = f'<div>{svg_code}</div>'

# 使用 IPython 的 display 模块来显示这个 HTML 标签
display(HTML(html_code))
# Out:
# <div>
# <svg width="200px" height="200px" viewBox="0 0 200 200" xmlns="http://www.w3.org/2000/svg">
#   <!-- 荔枝的主体 -->
#   <ellipse cx="100" cy="100" rx="50" ry="40" fill="#FF6347" />
#   <!-- 荔枝的叶子 -->
#   <path d="M100,60 Q90,20 110,20 Q120,40 100,60" fill="#228B22" />
#   <!-- 荔枝的纹理 -->
#   <circle cx="70" cy="90" r="5" fill="#FFFFFF" />
#   <circle cx="130" cy="90" r="5" fill="#FFFFFF" />
#   <circle cx="90" cy="110" r="5" fill="#FFFFFF" />
#   <circle cx="110" cy="110" r="5" fill="#FFFFFF" />
#   <!-- 荔枝的茎 -->
#   <line x1="100" y1="140" x2="100" y2="160" stroke="#8B4513" stroke-width="2" />
# </svg>
# </div>

# %% [markdown]
# 生成4个用于图标的svg图，分别是字母 CA、CT、CH、CS

# %% [markdown]
# 当然可以，以下是四个SVG图像，分别代表字母组合 "CH"、"CT"、"CH" 和 "CS"。每个图像都是一个简单的SVG格式，可以直接用于图标。
#
# 1. **CA.svg**
# ```svg
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <text x="10" y="50" font-family="Arial" font-size="40" fill="black">CA</text>
# </svg>
# ```
#
# 2. **CT.svg**
# ```svg
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <text x="10" y="50" font-family="Arial" font-size="40" fill="black">CT</text>
# </svg>
# ```
#
# 3. **CH.svg**
# ```svg
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <text x="10" y="50" font-family="Arial" font-size="40" fill="black">CH</text>
# </svg>
# ```
#
# 4. **CS.svg**
# ```svg
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <text x="10" y="50" font-family="Arial" font-size="40" fill="black">CS</text>
# </svg>
# ```
#
# 这些SVG图像可以直接插入到网页中或用于其他需要图标的场合。如果你需要不同的字体、颜色或大小，可以调整SVG代码中的相应属性。

# %%
display(HTML("""<svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
  <text x="0" y="8" font-family="Arial" font-size="8" fill="black">CA</text>
</svg>"""))
# Out:
# <svg width="100" height="100" xmlns="http://www.w3.org/2000/svg">
#   <text x="0" y="8" font-family="Arial" fill="black">CA</text>
# </svg>
